# %% [markdown]
# <a href="https://colab.research.google.com/github/rizwanriaz-se/Advanced_AI_Assignment/blob/main/Advanced_AI_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jabrane-mourad/ER-HAL.git
# Out:
# Cloning into 'ER-HAL'...
# remote: Enumerating objects: 208, done.
# remote: Counting objects: 100% (208/208), done.
# remote: Compressing objects: 100% (170/170), done.
# remote: Total 208 (delta 41), reused 203 (delta 36), pack-reused 0 (from 0)
# Receiving objects: 100% (208/208), 11.22 MiB | 16.20 MiB/s, done.
# Resolving deltas: 100% (41/41), done.

# %%
cd ER-HAL
# Out:
# /content/ER-HAL

# %%
pwd
# Out:
# '/content/ER-HAL'

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 75.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.4/115.4 kB 13.1 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !cat createFV/CTE.py
# Out:
# DATA_BASE ="S_iTunes_Amazon"
# # DATA_BASE ="S_Walmart-Amazon"
# # DATA_BASE ="S_BeerAdvo_RateBeer"
# # DATA_BASE ="S_Amazon_Google"
# # DATA_BASE ="S_Fodors_Zagats"
#
# # DATA_BASE ="D_wdc_headphones"
# # DATA_BASE ="D_wdc_phones"
# # DATA_BASE ="D_iTunes_Amazon"
# # DATA_BASE ="D_Walmart_Amazon"
#
# # DATA_BASE ="T_abt_buy"
# # DATA_BASE ="T_Amazon_Google"
#
# DATA_BASE_DIRECTORY = f'datasets/{DATA_BASE}'
# FEATURES_TRAIN_DIRECTORY = f'datasets/{DATA_BASE}/features_train'
# FEATURES_TEST_DIRECTORY = f'datasets/{DATA_BASE}/features_test'

# %%
# !python3 createFV/CTE.py

# %%
# !pip install Levenshtein gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 55.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 27.4 MB/s eta 0:00:00
# ...

# %%
pip install modal-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.8/125.8 kB 11.7 MB/s eta 0:00:00
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# Select dataset in cte.py, CTE.py and createFeatureVectorFile.py

# %%
# !python3 createFV/createFeatureVectorFile.py
# Out:
# Source file records: 6907
# Target file records: 55923
# Correspondences in the gold_standard_train: 321
# Correspondences in the gold_standard_test: 109
# Get types of data
# {'id': 'numeric', 'Song_Name': 'long_str', 'Artist_Name': 'str', 'Album_Name': 'str', 'Genre': 'long_str', 'Price': 'str', 'CopyRight': 'long_str', 'Time': 'str', 'Released': 'str'}
# {'id': 'numeric', 'Song_Name': 'long_str', 'Artist_Name': 'str', 'Album_Name': 'date', 'Genre': 'str', 'Price': 'str', 'CopyRight': 'long_str', 'Time': 'str', 'Released': 'str'}
# Different data types in source and target for element Genre. Will assign long string
# Different data types in source and target for element Album_Name. Will assign string
# Calculate tfidf scores
# Create similarity based features from 8 common elements
# Create Features: |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0% Complete
# Created 48 features for 322 entity pairs
# ...

# %%
pwd
# Out:
# '/content/ER-HAL'

# %%
# !python3 main.py
# Out:
#
#  ________DATABASE=D_iTunes_Amazon________
#
#
# dataset_train shape: (321, 48)
# dataset_test shape: (109, 48)
# X_train shape: (321, 44)
# X_test shape: (109, 44)
# choose a strategy (1) for DPQ, (2) for STQ  :    	1
# ni = 0
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# strategy == DPQ   ||   i==0  || Accuracy=0.7522935779816514	 Precision=0.0	 recall=0.0	F1=0.0
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# strategy == DPQ   ||   i==1  || Accuracy=0.7155963302752294	 Precision=0.0	 recall=0.0	F1=0.0
# ...

# %%
import pandas as pdb
df = pd.read_csv("/content/ER-HAL/result_graph/results_DPQ.csv")
print(df.tail(1));
# Out:
#      iteration  step  accuracy  precision    recall  f1_score
# 164          0   164  0.844037   0.678571  0.703704  0.690909

# %%
import matplotlib.pyplot as plt

# Your provided dictionaries (shortened for readability)
 0.7037037037037037, 0.6666666666666666, 0.6666666666666666, 0.6666666666666666, 0.6666666666666666, 0.6296296296296297, 0.6296296296296297, 0.6666666666666666, 0.6296296296296297, 0.6666666666666666, 0.6666666666666666, 0.6666666666666666, 0.7037037037037037, 0.7037037037037037, 0.7037037037037037, 0.7037037037037037, 0.6666666666666666, 0.6666666666666666, 0.6296296296296297, 0.7037037037037037, 0.6666666666666666, 0.7037037037037037, 0.7037037037037037, 0.7037037037037037, 0.6666666666666666, 0.6666666666666666, 0.6296296296296297, 0.7037037037037037, 0.7407407407407407, 0.6296296296296297, 0.6296296296296297, 0.5925925925925926, 0.6296296296296297, 0.6296296296296297, 0.6666666666666666, 0.7037037037037037, 0.5925925925925926, 0.5925925925925926, 0.6296296296296297, 0.7037037037037037, 0.6666666666666666, 0.6296296296296297, 0.6666666666666666, 0.6296296296296297, 0.7777777777777778, 0.7037037037037037, 0.6666666666666666, 0.6666666666666666, 0.7037037037037037, 0.7037037037037037, 0.6666666666666666, 0.6296296296296297, 0.7037037037037037, 0.5925925925925926, 0.6666666666666666, 0.7037037037037037, 0.6296296296296297, 0.6296296296296297, 0.7037037037037037, 0.6296296296296297, 0.7037037037037037, 0.5925925925925926, 0.6666666666666666, 0.6666666666666666, 0.6296296296296297, 0.7037037037037037, 0.6296296296296297, 0.6666666666666666, 0.6666666666666666, 0.7407407407407407, 0.7037037037037037, 0.6296296296296297, 0.5925925925925926, 0.6666666666666666, 0.6296296296296297, 0.7037037037037037, 0.7037037037037037, 0.7037037037037037, 0.7037037037037037, 0.6666666666666666, 0.6666666666666666, 0.7037037037037037, 0.6296296296296297, 0.6296296296296297, 0.6296296296296297, 0.6296296296296297, 0.6666666666666666, 0.6296296296296297, 0.7037037037037037, 0.6666666666666666, 0.6296296296296297, 0.5925925925925926, 0.6296296296296297, 0.5925925925925926, 0.7407407407407407, 0.6666666666666666, 0.6666666666666666, 0.7037037037037037, 0.6296296296296297, 0.6666666666666666, 0.6296296296296297, 0.5925925925925926, 0.6666666666666666, 0.7037037037037037, 0.6666666666666666]]}

# Extract data for plotting
# x = list(range(len(F1['DPQ'][0])))   # X-axis values (like epochs)
# f1_values = F1['DPQ'][0]
# acc_values = Accuracy['DPQ'][0]
# prec_values = Precision['DPQ'][0]
# rec_values = Recall['DPQ'][0]

strategy = "DPQ"  # or "STQ" update this
df = pd.read_csv(f"result_graph/results_{strategy}.csv")
# Group by step (averaging across iterations)
mean_df = df.groupby("step")[["accuracy", "precision", "recall", "f1_score"]].mean().reset_index()

# Plot all metrics
plt.figure(figsize=(10, 6))
plt.plot(mean_df["step"], mean_df["accuracy"], label="Accuracy", linewidth=2)
plt.plot(mean_df["step"], mean_df["precision"], label="Precision", linewidth=2)
plt.plot(mean_df["step"], mean_df["recall"], label="Recall", linewidth=2)
plt.plot(mean_df["step"], mean_df["f1_score"], label="F1 Score", linewidth=2)

# Labels, title, legend
plt.xlabel("Step", fontsize=12)
plt.ylabel("Score", fontsize=12)
plt.title("Model Performance Over Steps", fontsize=14)
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)

# Save and show
plt.tight_layout()
plt.savefig("result_graph/metrics_plot.png", dpi=300)
plt.show()
# plt.figure(figsize=(10,6))
# plt.plot(df["iteration"], df["f1_score"], label="F1", linewidth=2)
# plt.plot(df["iteration"], df["accuracy"], label="Accuracy", linewidth=2)
# plt.plot(df["iteration"], df["precision"], label="Precision", linewidth=2)
# plt.plot(df["iteration"], df["recall"], label="Recall", linewidth=2)

# # Plot all four metrics
# plt.figure(figsize=(10,6))
# # plt.plot(x, f1_values, label='F1 Score', linewidth=2)
# # plt.plot(x, acc_values, label='Accuracy', linewidth=2)
# # plt.plot(x, prec_values, label='Precision', linewidth=2)
# # plt.plot(x, rec_values, label='Recall', linewidth=2)

# plt.xlabel('Epochs or Steps')
# plt.ylabel('Metric Value')
# plt.title('Model Performance Metrics Over Time')
# plt.legend()
# plt.grid(True)
# plt.show()
